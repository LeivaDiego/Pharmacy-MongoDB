# %% [markdown]
# # Datos base

# %% [markdown]
# ## Exploracion y preprocesamiento del dataset

# %% [markdown]
# **Librerias necesarias**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Cargar los dataset al entorno**

# %%
data1 = pd.read_csv("A_Z_medicines_dataset_of_India.csv")
data2 = pd.read_csv("medicine_dataset.csv", 
                  dtype={42: 'str', 43: 'str', 44: 'str', 45: 'str', 46: 'str', 47: 'str', 48: 'str'})

# Tomar una muestra de 50,000 medicinas aleatorias
df1 = data1.sample(n=50000, random_state=1)
df2 = data2.sample(n=50000, random_state=1)

# %% [markdown]
# Datasets obtenidos de:
# - https://www.kaggle.com/datasets/shudhanshusingh/250k-medicines-usage-side-effects-and-substitutes
# - https://www.kaggle.com/datasets/shudhanshusingh/az-medicine-dataset-of-india

# %% [markdown]
# **Visualizar información general de los dataset**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 253316 to 56376
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  50000 non-null  int64
#  1   name                50000 non-null  object
#  2   price(₹)            50000 non-null  float64
#  3   Is_discontinued     50000 non-null  bool
#  4   manufacturer_name   50000 non-null  object
#  5   type                50000 non-null  object
#  6   pack_size_label     50000 non-null  object
#  7   short_composition1  50000 non-null  object
#  8   short_composition2  22113 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50000 entries, 16454 to 54321
# Data columns (total 58 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50000 non-null  int64
#  1   name               50000 non-null  object
#  2   substitute0        48084 non-null  object
#  3   substitute1        47128 non-null  object
#  4   substitute2        46397 non-null  object
#  5   substitute3        45708 non-null  object
#  6   substitute4        45135 non-null  object
#  7   sideEffect0        50000 non-null  object
#  8   sideEffect1        48035 non-null  object
#  9   sideEffect2        46235 non-null  object
#  10  sideEffect3        41953 non-null  object
#  11  sideEffect4        33032 non-null  object
#  12  sideEffect5        26388 non-null  object
#  13  sideEffect6        18558 non-null  object
#  14  sideEffect7        13710 non-null  object
#  15  sideEffect8        9802 non-null   object
#  16  sideEffect9        7600 non-null   object
#  17  sideEffect10       5499 non-null   object
#  18  sideEffect11       4106 non-null   object
#  19  sideEffect12       3283 non-null   object
#  20  sideEffect13       2964 non-null   object
#  21  sideEffect14       2109 non-null   object
#  22  sideEffect15       1586 non-null   object
#  23  sideEffect16       1236 non-null   object
#  24  sideEffect17       1101 non-null   object
#  25  sideEffect18       936 non-null    object
#  26  sideEffect19       812 non-null    object
#  27  sideEffect20       665 non-null    object
#  28  sideEffect21       649 non-null    object
#  29  sideEffect22       629 non-null    object
#  30  sideEffect23       598 non-null    object
#  31  sideEffect24       563 non-null    object
#  32  sideEffect25       309 non-null    object
#  33  sideEffect26       309 non-null    object
#  34  sideEffect27       308 non-null    object
#  35  sideEffect28       308 non-null    object
#  36  sideEffect29       296 non-null    object
#  37  sideEffect30       275 non-null    object
#  38  sideEffect31       275 non-null    object
#  39  sideEffect32       275 non-null    object
#  40  sideEffect33       239 non-null    object
#  41  sideEffect34       239 non-null    object
#  42  sideEffect35       1 non-null      object
#  43  sideEffect36       1 non-null      object
#  44  sideEffect37       1 non-null      object
#  45  sideEffect38       1 non-null      object
#  46  sideEffect39       1 non-null      object
#  47  sideEffect40       1 non-null      object
#  48  sideEffect41       1 non-null      object
#  49  use0               50000 non-null  object
#  50  use1               14575 non-null  object
#  51  use2               5635 non-null   object
#  52  use3               1460 non-null   object
#  53  use4               1005 non-null   object
#  54  Chemical Class     27531 non-null  object
#  55  Habit Forming      50000 non-null  object
#  56  Therapeutic Class  49992 non-null  object
#  57  Action Class       27582 non-null  object
# dtypes: int64(1), object(57)
# memory usage: 22.5+ MB

# %% [markdown]
# **Visualizar estructura de los dataset**

# %%
df1.head()
# Out:
#             id                              name  price(₹)  Is_discontinued  \
# 253316  253317  Zingcef S 1000mg/500mg Injection    150.00            False
# 223357  223358      Teldil R 40 mg/2.5 mg Tablet     72.11            False
# 40869    40870                 Clotas 2mg Tablet     89.00            False
# 160475  160476             Nanfit 25mg Injection     79.00            False
# 104602  104603                Hinac 100mg Tablet     28.15            False
#
#                      manufacturer_name       type      pack_size_label  \
# 253316  Swakam Biotech Private Limited  allopathy  vial of 1 Injection
# 223357           Pulse Pharmaceuticals  allopathy  strip of 10 tablets
# 40869            Tas Med India Pvt Ltd  allopathy  strip of 10 tablets
# 160475            Elgoog Health Series  allopathy  vial of 1 Injection
# 104602       Intas Pharmaceuticals Ltd  allopathy  strip of 10 tablets
#
#                  short_composition1  short_composition2
# 253316        Ceftriaxone (1000mg)    Sulbactam (500mg)
# 223357          Telmisartan (40mg)     Ramipril (2.5mg)
# 40869              Clonazepam (2mg)                 NaN
# 160475  Nandrolone Decanoate (25mg)                 NaN
# 104602          Aceclofenac (100mg)                 NaN

# %%
df2.head()
# Out:
#             id                           name  \
# 16454    16455                 alcuf-dx syrup
# 158022  158023              morclav dry syrup
# 18205    18206       ampurin 1000mg injection
# 102557  102558  glimiprime-m2 forte tablet pr
# 152804  152805         monvoc 5mg/10mg tablet
#
#                              substitute0                   substitute1  \
# 16454                 Alkof Junior Syrup             Respicure-D Syrup
# 158022  Mokcan CV 200mg/28.5mg Dry Syrup      Clavmentin Duo Dry Syrup
# 18205              Ampi 1000mg Injection         Ampy 1000mg Injection
# 102557    Glimiprex MF Forte 2 Tablet PR  Glimestar-M2 Forte Tablet PR
# 152804                  Montina-L Tablet               Solitair Tablet
#
#                               substitute2                   substitute3  \
# 16454                      Chericof Syrup             Respicure-D Syrup
# 158022  Xtraclav 200 mg/28.5 mg Dry Syrup              Mpx-CV Dry Syrup
# 18205            Cidalin 1000mg Injection     Ulcillin 1000mg Injection
# 102557         Geminor M2 Forte Tablet PR  Glimisave M2 Forte Tablet PR
# 152804                    Lecope-M Tablet              Monticope Tablet
#
#                               substitute4  \
# 16454                       Ataqued Syrup
# 158022  Clavituf 200 mg/28.5 mg Dry Syrup
# 18205                                 NaN
# 102557    Glimisave Max Forte 2 Tablet PR
# 152804                   Levocet M Tablet
#
#                                               sideEffect0 sideEffect1  \
# 16454                                              Nausea    Vomiting
# 158022                                             Nausea    Vomiting
# 18205   Injection site reactions (pain, swelling, redn...         NaN
# 102557             Hypoglycemia (low blood glucose level)    Headache
# 152804                                             Nausea    Diarrhea
#
#              sideEffect2  ... sideEffect41  \
# 16454   Loss of appetite  ...          NaN
# 158022    Abdominal pain  ...          NaN
# 18205                NaN  ...          NaN
# 102557            Nausea  ...          NaN
# 152804  Dryness in mouth  ...          NaN
#
#                                                      use0  \
# 16454                              Treatment of Dry cough
# 158022          Treatment of Resistance Tuberculosis (TB)
# 18205                                Bacterial infections
# 102557              Treatment of Type 2 diabetes mellitus
# 152804  Treatment of Sneezing and runny nose due to al...
#
#                                      use1  \
# 16454                                 NaN
# 158022  Treatment of Bacterial infections
# 18205                                 NaN
# 102557                                NaN
# 152804             Treatment of Hay fever
#
#                                          use2 use3 use4  \
# 16454                                     NaN  NaN  NaN
# 158022                                    NaN  NaN  NaN
# 18205                                     NaN  NaN  NaN
# 102557                                    NaN  NaN  NaN
# 152804  Treatment of Allergic skin conditions  NaN  NaN
#
#                         Chemical Class Habit Forming Therapeutic Class  \
# 16454                              NaN            No       RESPIRATORY
# 158022                             NaN            No   ANTI INFECTIVES
# 18205   Aminopenicillins {Penicillins}            No   ANTI INFECTIVES
# 102557                             NaN            No     ANTI DIABETIC
# 152804                             NaN            No       RESPIRATORY
#
#                                              Action Class
# 16454                                                 NaN
# 158022                                                NaN
# 18205   Cell wall active agent -Extended spectrum Peni...
# 102557                                                NaN
# 152804                                                NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# **Verificar existencia de valores nulos**

# %%
df1.isnull().sum()
# Out:
# id                        0
# name                      0
# price(₹)                  0
# Is_discontinued           0
# manufacturer_name         0
# type                      0
# pack_size_label           0
# short_composition1        0
# short_composition2    27887
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# id                       0
# name                     0
# substitute0           1916
# substitute1           2872
# substitute2           3603
# substitute3           4292
# substitute4           4865
# sideEffect0              0
# sideEffect1           1965
# sideEffect2           3765
# sideEffect3           8047
# sideEffect4          16968
# sideEffect5          23612
# sideEffect6          31442
# sideEffect7          36290
# sideEffect8          40198
# sideEffect9          42400
# sideEffect10         44501
# sideEffect11         45894
# sideEffect12         46717
# sideEffect13         47036
# sideEffect14         47891
# sideEffect15         48414
# sideEffect16         48764
# sideEffect17         48899
# sideEffect18         49064
# sideEffect19         49188
# sideEffect20         49335
# sideEffect21         49351
# sideEffect22         49371
# sideEffect23         49402
# sideEffect24         49437
# sideEffect25         49691
# sideEffect26         49691
# sideEffect27         49692
# sideEffect28         49692
# sideEffect29         49704
# sideEffect30         49725
# sideEffect31         49725
# sideEffect32         49725
# sideEffect33         49761
# sideEffect34         49761
# sideEffect35         49999
# sideEffect36         49999
# sideEffect37         49999
# sideEffect38         49999
# sideEffect39         49999
# sideEffect40         49999
# sideEffect41         49999
# use0                     0
# use1                 35425
# use2                 44365
# use3                 48540
# use4                 48995
# Chemical Class       22469
# Habit Forming            0
# Therapeutic Class        8
# Action Class         22418
# dtype: int64

# %% [markdown]
# Se considera que por cuestiones de simplicidad y dado que muchos campos tienen gran cantidad de nulos, se conservaran solo los primeros 5 efectos secundarios, y los primeros 3 substitutos.

# %% [markdown]
# **Selección de características relevantes**

# %%
columns_a = [
    'name', 
    'price(₹)', 
    'Is_discontinued', 
    'manufacturer_name', 
    'pack_size_label',
    'short_composition1',
    'short_composition2'
]

features_a = df1[columns_a]

# %%
columns_b = [
    'name', 
    'substitute0',
    'substitute1',
    'substitute2',
    'substitute3',
    'substitute4',
    'sideEffect0',
    'sideEffect1',
    'sideEffect2',
    'sideEffect3',
    'sideEffect4',
    'use0',
    'use1',
    'use2',
    'use3',
    'use4',
    'Therapeutic Class'
]

features_b = df2[columns_b]

# %% [markdown]
# **Eliminacion de medicamentos duplicados**

# %%
features_a['name'].duplicated().sum()
# Out:
# 188

# %%
features_b['name'].duplicated().sum()
# Out:
# 1109

# %% [markdown]
# Existen varias instancias de medicamentos duplicados, por lo que se procede a conservar solo la primera instancia encontrada

# %%
features_a = features_a.drop_duplicates(subset=['name'], keep='first')
features_b = features_b.drop_duplicates(subset=['name'], keep='first')

# %% [markdown]
# **Combinacion de datasets**

# %%
features_a.loc[:, 'name'] = features_a['name'].str.lower()
features_b.loc[:, 'name'] = features_b['name'].str.lower()
features_b.loc[:, 'Therapeutic Class'] = features_b['Therapeutic Class'].str.lower()


df = pd.merge(features_a, features_b, on='name', how='inner')

# %% [markdown]
# **Visualizar nuevo dataframe**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10032 entries, 0 to 10031
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                10032 non-null  object
#  1   price(₹)            10032 non-null  float64
#  2   Is_discontinued     10032 non-null  bool
#  3   manufacturer_name   10032 non-null  object
#  4   pack_size_label     10032 non-null  object
#  5   short_composition1  10032 non-null  object
#  6   short_composition2  4366 non-null   object
#  7   substitute0         9597 non-null   object
#  8   substitute1         9398 non-null   object
#  9   substitute2         9275 non-null   object
#  10  substitute3         9148 non-null   object
#  11  substitute4         9028 non-null   object
#  12  sideEffect0         10032 non-null  object
#  13  sideEffect1         9608 non-null   object
#  14  sideEffect2         9258 non-null   object
#  15  sideEffect3         8414 non-null   object
#  16  sideEffect4         6605 non-null   object
#  17  use0                10032 non-null  object
#  18  use1                2966 non-null   object
#  19  use2                1157 non-null   object
#  20  use3                297 non-null    object
#  21  use4                205 non-null    object
#  22  Therapeutic Class   10031 non-null  object
# dtypes: bool(1), float64(1), object(21)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#                                name  price(₹)  Is_discontinued  \
# 0  zingcef s 1000mg/500mg injection    150.00            False
# 1             nanfit 25mg injection     79.00            False
# 2                hinac 100mg tablet     28.15            False
# 3               olumiant 2mg tablet  21144.00            False
# 4                   sorbiline syrup    153.50            False
#
#                        manufacturer_name         pack_size_label  \
# 0         Swakam Biotech Private Limited     vial of 1 Injection
# 1                   Elgoog Health Series     vial of 1 Injection
# 2              Intas Pharmaceuticals Ltd     strip of 10 tablets
# 3    Eli Lilly and Company India Pvt Ltd      strip of 7 tablets
# 4  Franco-Indian Pharmaceuticals Pvt Ltd  bottle of 200 ml Syrup
#
#              short_composition1  short_composition2  \
# 0         Ceftriaxone (1000mg)    Sulbactam (500mg)
# 1   Nandrolone Decanoate (25mg)                 NaN
# 2           Aceclofenac (100mg)                 NaN
# 3             Baricitinib (2mg)                 NaN
# 4  Tricholine Citrate (0.55gm)    Sorbitol (7.15gm)
#
#                           substitute0                        substitute1  \
# 0  Effimax S 1000 mg/500 mg Injection  Trixon S 1000 mg/500 mg Injection
# 1            Nandrolin 25mg Injection                 Ndr 25mg Injection
# 2                 Topnac 100mg Tablet               Topflam 100mg Tablet
# 3                                 NaN                                NaN
# 4                      Choliv-L Syrup                      AL Live Syrup
#
#               substitute2  ...                   sideEffect1  \
# 0  Big-Tum 1.5G Injection  ...       Increased liver enzymes
# 1   Velbol 25mg Injection  ...                        Nausea
# 2     Acenal 100mg Tablet  ...  Stomach pain/epigastric pain
# 3                     NaN  ...                        Nausea
# 4           Glysorb Syrup  ...                    Drowsiness
#
#               sideEffect2  sideEffect3      sideEffect4  \
# 0       Allergic reaction         Rash              NaN
# 1      Breast enlargement         Acne              NaN
# 2                  Nausea  Indigestion         Diarrhea
# 3  Herpes virus infection   Cold sores  Viral infection
# 4                     NaN          NaN              NaN
#
#                                         use0 use1 use2 use3 use4  \
# 0                       Bacterial infections  NaN  NaN  NaN  NaN
# 1  Treatment of Post menopausal osteoporosis  NaN  NaN  NaN  NaN
# 2                                Pain relief  NaN  NaN  NaN  NaN
# 3                       Rheumatoid arthritis  NaN  NaN  NaN  NaN
# 4                        Fatty liver disease  NaN  NaN  NaN  NaN
#
#              Therapeutic Class
# 0              anti infectives
# 1                     hormones
# 2              pain analgesics
# 3              pain analgesics
# 4  vitamins minerals nutrients
#
# [5 rows x 23 columns]

# %% [markdown]
# **Eliminacion de medicamentos descontinuados**

# %% [markdown]
# Dado que a una farmacia no le sirve tener medicamentos descontinuados se procede a eliminarlos de la data inicial.

# %%
# Eliminar todos los medicamentos descontinuados
df = df[df['Is_discontinued']== False]

# Eliminar la columna Is_discontinued
df.drop('Is_discontinued', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                name  price(₹)  \
# 0  zingcef s 1000mg/500mg injection    150.00
# 1             nanfit 25mg injection     79.00
# 2                hinac 100mg tablet     28.15
# 3               olumiant 2mg tablet  21144.00
# 4                   sorbiline syrup    153.50
#
#                        manufacturer_name         pack_size_label  \
# 0         Swakam Biotech Private Limited     vial of 1 Injection
# 1                   Elgoog Health Series     vial of 1 Injection
# 2              Intas Pharmaceuticals Ltd     strip of 10 tablets
# 3    Eli Lilly and Company India Pvt Ltd      strip of 7 tablets
# 4  Franco-Indian Pharmaceuticals Pvt Ltd  bottle of 200 ml Syrup
#
#              short_composition1  short_composition2  \
# 0         Ceftriaxone (1000mg)    Sulbactam (500mg)
# 1   Nandrolone Decanoate (25mg)                 NaN
# 2           Aceclofenac (100mg)                 NaN
# 3             Baricitinib (2mg)                 NaN
# 4  Tricholine Citrate (0.55gm)    Sorbitol (7.15gm)
#
#                           substitute0                        substitute1  \
# 0  Effimax S 1000 mg/500 mg Injection  Trixon S 1000 mg/500 mg Injection
# 1            Nandrolin 25mg Injection                 Ndr 25mg Injection
# 2                 Topnac 100mg Tablet               Topflam 100mg Tablet
# 3                                 NaN                                NaN
# 4                      Choliv-L Syrup                      AL Live Syrup
#
#               substitute2                        substitute3  ...  \
# 0  Big-Tum 1.5G Injection  Extacef XL 1000mg/500mg Injection  ...
# 1   Velbol 25mg Injection           Sensinorm 25mg Injection  ...
# 2     Acenal 100mg Tablet              Safronac 100mg Tablet  ...
# 3                     NaN                                NaN  ...
# 4           Glysorb Syrup                        Soliv Syrup  ...
#
#                     sideEffect1             sideEffect2  sideEffect3  \
# 0       Increased liver enzymes       Allergic reaction         Rash
# 1                        Nausea      Breast enlargement         Acne
# 2  Stomach pain/epigastric pain                  Nausea  Indigestion
# 3                        Nausea  Herpes virus infection   Cold sores
# 4                    Drowsiness                     NaN          NaN
#
#        sideEffect4                                       use0 use1 use2 use3  \
# 0              NaN                       Bacterial infections  NaN  NaN  NaN
# 1              NaN  Treatment of Post menopausal osteoporosis  NaN  NaN  NaN
# 2         Diarrhea                                Pain relief  NaN  NaN  NaN
# 3  Viral infection                       Rheumatoid arthritis  NaN  NaN  NaN
# 4              NaN                        Fatty liver disease  NaN  NaN  NaN
#
#   use4            Therapeutic Class
# 0  NaN              anti infectives
# 1  NaN                     hormones
# 2  NaN              pain analgesics
# 3  NaN              pain analgesics
# 4  NaN  vitamins minerals nutrients
#
# [5 rows x 22 columns]

# %% [markdown]
# **Nuevo etiquetado de columnas**

# %%
# Cambiar los nombres de las columnas a español
nuevas_etiquetas = {
    'name': 'nombre',
    'price(₹)': 'precio',
    'manufacturer_name': 'fabricante',
    'pack_size_label': 'presentacion',
    'short_composition1': 'composicion1',
    'short_composition2': 'composicion2',
    'substitute0': 'sustituto0',
    'substitute1': 'sustituto1',
    'substitute2': 'sustituto2',
    'substitute3': 'sustituto3',
    'substitute4': 'sustituto4',
    'sideEffect0': 'efecto_secundario0',
    'sideEffect1': 'efecto_secundario1',
    'sideEffect2': 'efecto_secundario2',
    'use0': 'uso0',
    'use1': 'uso1',
    'use2': 'uso2',
    'use3': 'uso3',
    'use4': 'uso4',
    'Therapeutic Class': 'clase_terapeutica'
}

df.rename(columns=nuevas_etiquetas, inplace=True)

# %% [markdown]
# **Conversion de rupia india a quetzal**

# %%
# Conversión de precios de rupias a quetzales
# 1 rupia india = 0.094 quetzales guatemaltecos
tasa_cambio = 0.094
df['precio'] = df['precio'] * tasa_cambio
df['precio'] = df['precio'].round(2)

# %%
df.head()
# Out:
#                              nombre   precio  \
# 0  zingcef s 1000mg/500mg injection    14.10
# 1             nanfit 25mg injection     7.43
# 2                hinac 100mg tablet     2.65
# 3               olumiant 2mg tablet  1987.54
# 4                   sorbiline syrup    14.43
#
#                               fabricante            presentacion  \
# 0         Swakam Biotech Private Limited     vial of 1 Injection
# 1                   Elgoog Health Series     vial of 1 Injection
# 2              Intas Pharmaceuticals Ltd     strip of 10 tablets
# 3    Eli Lilly and Company India Pvt Ltd      strip of 7 tablets
# 4  Franco-Indian Pharmaceuticals Pvt Ltd  bottle of 200 ml Syrup
#
#                    composicion1        composicion2  \
# 0         Ceftriaxone (1000mg)    Sulbactam (500mg)
# 1   Nandrolone Decanoate (25mg)                 NaN
# 2           Aceclofenac (100mg)                 NaN
# 3             Baricitinib (2mg)                 NaN
# 4  Tricholine Citrate (0.55gm)    Sorbitol (7.15gm)
#
#                            sustituto0                         sustituto1  \
# 0  Effimax S 1000 mg/500 mg Injection  Trixon S 1000 mg/500 mg Injection
# 1            Nandrolin 25mg Injection                 Ndr 25mg Injection
# 2                 Topnac 100mg Tablet               Topflam 100mg Tablet
# 3                                 NaN                                NaN
# 4                      Choliv-L Syrup                      AL Live Syrup
#
#                sustituto2                         sustituto3  ...  \
# 0  Big-Tum 1.5G Injection  Extacef XL 1000mg/500mg Injection  ...
# 1   Velbol 25mg Injection           Sensinorm 25mg Injection  ...
# 2     Acenal 100mg Tablet              Safronac 100mg Tablet  ...
# 3                     NaN                                NaN  ...
# 4           Glysorb Syrup                        Soliv Syrup  ...
#
#              efecto_secundario1      efecto_secundario2  sideEffect3  \
# 0       Increased liver enzymes       Allergic reaction         Rash
# 1                        Nausea      Breast enlargement         Acne
# 2  Stomach pain/epigastric pain                  Nausea  Indigestion
# 3                        Nausea  Herpes virus infection   Cold sores
# 4                    Drowsiness                     NaN          NaN
#
#        sideEffect4                                       uso0 uso1 uso2 uso3  \
# 0              NaN                       Bacterial infections  NaN  NaN  NaN
# 1              NaN  Treatment of Post menopausal osteoporosis  NaN  NaN  NaN
# 2         Diarrhea                                Pain relief  NaN  NaN  NaN
# 3  Viral infection                       Rheumatoid arthritis  NaN  NaN  NaN
# 4              NaN                        Fatty liver disease  NaN  NaN  NaN
#
#   uso4            clase_terapeutica
# 0  NaN              anti infectives
# 1  NaN                     hormones
# 2  NaN              pain analgesics
# 3  NaN              pain analgesics
# 4  NaN  vitamins minerals nutrients
#
# [5 rows x 22 columns]

# %% [markdown]
# **Verificacion de existencia de valores nulos en campos importantes**

# %%
df = df.dropna(subset=['clase_terapeutica'])

# %%
df.isnull().sum()
# Out:
# nombre                   0
# precio                   0
# fabricante               0
# presentacion             0
# composicion1             0
# composicion2          5466
# sustituto0             399
# sustituto1             584
# sustituto2             698
# sustituto3             821
# sustituto4             930
# efecto_secundario0       0
# efecto_secundario1     403
# efecto_secundario2     739
# sideEffect3           1556
# sideEffect4           3314
# uso0                     0
# uso1                  6860
# uso2                  8609
# uso3                  9445
# uso4                  9532
# clase_terapeutica        0
# dtype: int64

# %% [markdown]
# Todos los medicamentos tienen por lo menos un componente en su composicion quimica, no todos tienen substitutos, todos causan algun efecto secundario, y todos tienen por lo menos un uso, y todos tienen clase terapeutica.

# %% [markdown]
# **Reestructuracion del dataframe**

# %% [markdown]
# El documento para un medicamento se vera de la siguiente manera:
#
# ![image.png](attachment:image.png)

# %%
# Preparar los datos para la nueva estructura
new_data = df.apply(lambda x: {
    "nombre": x['nombre'],
    "precio": x['precio'],
    "fabricante": x['fabricante'],
    "presentacion": x['presentacion'],
    "detalles": {
        "composicion": [comp for comp in [x['composicion1'], x.get('composicion2', '')] if pd.notna(comp) and comp != ''],
        "efectos_secundarios": [x[f'efecto_secundario{i}'] for i in range(3) if pd.notna(x.get(f'efecto_secundario{i}', '')) and x.get(f'efecto_secundario{i}', '') != ''],
        "usos": [x[f'uso{i}'] for i in range(5) if pd.notna(x.get(f'uso{i}', '')) and x.get(f'uso{i}', '') != '']
    },
    "sustitutos": [x[f'sustituto{i}'] for i in range(5) if pd.notna(x.get(f'sustituto{i}', '')) and x.get(f'sustituto{i}', '') != ''],
    "clase_terapeutica": x['clase_terapeutica']
}, axis=1).tolist()



# Crear un nuevo DataFrame con la estructura deseada
final_df = pd.DataFrame(new_data)

final_df.head()
# Out:
#                              nombre   precio  \
# 0  zingcef s 1000mg/500mg injection    14.10
# 1             nanfit 25mg injection     7.43
# 2                hinac 100mg tablet     2.65
# 3               olumiant 2mg tablet  1987.54
# 4                   sorbiline syrup    14.43
#
#                               fabricante            presentacion  \
# 0         Swakam Biotech Private Limited     vial of 1 Injection
# 1                   Elgoog Health Series     vial of 1 Injection
# 2              Intas Pharmaceuticals Ltd     strip of 10 tablets
# 3    Eli Lilly and Company India Pvt Ltd      strip of 7 tablets
# 4  Franco-Indian Pharmaceuticals Pvt Ltd  bottle of 200 ml Syrup
#
#                                             detalles  \
# 0  {'composicion': ['Ceftriaxone (1000mg) ', ' Su...
# 1  {'composicion': ['Nandrolone Decanoate (25mg)'...
# 2  {'composicion': ['Aceclofenac (100mg)'], 'efec...
# 3  {'composicion': ['Baricitinib (2mg)'], 'efecto...
# 4  {'composicion': ['Tricholine Citrate (0.55gm) ...
#
#                                           sustitutos  \
# 0  [Effimax S 1000 mg/500 mg Injection, Trixon S ...
# 1  [Nandrolin 25mg Injection, Ndr 25mg Injection,...
# 2  [Topnac 100mg Tablet, Topflam 100mg Tablet, Ac...
# 3                                                 []
# 4  [Choliv-L Syrup, AL Live Syrup, Glysorb Syrup,...
#
#              clase_terapeutica
# 0              anti infectives
# 1                     hormones
# 2              pain analgesics
# 3              pain analgesics
# 4  vitamins minerals nutrients

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9730 entries, 0 to 9729
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nombre             9730 non-null   object
#  1   precio             9730 non-null   float64
#  2   fabricante         9730 non-null   object
#  3   presentacion       9730 non-null   object
#  4   detalles           9730 non-null   object
#  5   sustitutos         9730 non-null   object
#  6   clase_terapeutica  9730 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 532.2+ KB

# %%
final_df.shape
# Out:
# (9730, 7)

# %% [markdown]
# **Conversión a JSON y Carga en MongoDB**

# %%
from pymongo import MongoClient

uri = "mongodb+srv://lei21752:pux2912@cluster.xjohdzx.mongodb.net/?retryWrites=true&w=majority&appName=Cluster"

# Crear una instancia del cliente de MongoDB y conectarse ala DB
client = MongoClient(uri)

# Seleccionar la base de datos y la coleccion
db = client.farmacia
collection = db.medicamentos

# Dividir la data por lotes para evitar time out
batch_size = 1000
total_documents = len(new_data)
inserted_documents = 0

for i in range(0, total_documents, batch_size):
    batch = new_data[i:i+batch_size]
    collection.insert_many(batch)
    inserted_documents += len(batch)
    print(f"Documentos insertados: {inserted_documents}/{total_documents}")

print("Insercion completada.")
# Out:
# Documentos insertados: 1000/9730
# Documentos insertados: 2000/9730
# Documentos insertados: 3000/9730
# Documentos insertados: 4000/9730
# Documentos insertados: 5000/9730
# Documentos insertados: 6000/9730
# Documentos insertados: 7000/9730
# Documentos insertados: 8000/9730
# Documentos insertados: 9000/9730
# Documentos insertados: 9730/9730
# Insercion completada.

# %% [markdown]
# Data presente en Atlas:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Creacion de registros de inventarios**

# %%
import random
from datetime import datetime, timedelta

# Obtener todos los medicamentos
medicines = db.medicamentos.find()

# Coleccion de lotes
stock_collection = db.inventario

batches = []
for medicine in medicines:
    batch = {
        "medicamento_id": medicine["_id"],
        "cantidad": random.randint(10, 100),  # Cantidad aleatoria entre 10 y 100
        "fecha_vencimiento": (datetime.now() + timedelta(days=random.randint(180, 720))),  # Fecha de vencimiento aleatoria entre 6 meses y 2 años
    }
    batches.append(batch)

# Insertar lotes en la base de datos
stock_collection.insert_many(batches)
print("Lotes generados e insertados.")
# Out:
# Lotes generados e insertados.

# %% [markdown]
# Data presente en Atlas:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Creacion de registros de ventas**

# %%
# Obtener todos los medicamentos
medicaments = list(db.medicamentos.find())

# Colección de ventas
sales_collection = db.ventas

sales = []
inserted_sales = 0 

start_date = datetime(2022, 1, 1)  # Fecha de inicio para el rango de fechas de venta
today = datetime.now()  # Fecha actual

for _ in range(50000):  # Generar 50,000 ventas
    medicine_qty = random.randint(1, 3)  # De 1 a 3 medicamentos por venta
    items = random.sample(medicaments, medicine_qty)  # Seleccionar medicamentos aleatorios
    sale_items = []
    sale_total = 0
    for item in items:
        quantity = random.randint(1, 5)  # Cantidad de cada medicamento de 1 a 5
        price = item["precio"]
        subtotal = round(quantity * price, 2)
        sale_total += subtotal
        sale_items.append({
            "medicamento_id": item["_id"],
            "cantidad": quantity,
            "precio_unitario": price,
            "subtotal": subtotal
        })

    # Generar fecha de venta aleatoria dentro del rango especificado
    dias_entre_inicio_y_hoy = (today - start_date).days
    dias_aleatorios = random.randint(0, dias_entre_inicio_y_hoy)
    fecha_venta_aleatoria = start_date + timedelta(days=dias_aleatorios)

    venta = {
        "fecha_venta": fecha_venta_aleatoria,
        "items": sale_items,
        "total_venta": round(sale_total, 2),
        "metodo_pago": random.choice(["efectivo", "tarjeta"])
    }
    sales.append(venta)

    # Insertar en lotes para evitar sobrecarga
    if len(sales) >= 1000:
        sales_collection.insert_many(sales)
        inserted_sales += len(sales)  # Actualizar el contador
        print(f"Ventas insertadas: {inserted_sales}/50000")  # Mostrar el progreso
        sales = []  # Reiniciar la lista de ventas para el siguiente lote

# Insertar los restantes si los hay
if sales:
    sales_collection.insert_many(sales)
    inserted_sales += len(sales)  # Actualizar el contador final

print(f"Registros de ventas generados e insertados")
# Out:
# Ventas insertadas: 1000/50000
# Ventas insertadas: 2000/50000
# Ventas insertadas: 3000/50000
# Ventas insertadas: 4000/50000
# Ventas insertadas: 5000/50000
# Ventas insertadas: 6000/50000
# Ventas insertadas: 7000/50000
# Ventas insertadas: 8000/50000
# Ventas insertadas: 9000/50000
# Ventas insertadas: 10000/50000
# Ventas insertadas: 11000/50000
# Ventas insertadas: 12000/50000
# Ventas insertadas: 13000/50000
# Ventas insertadas: 14000/50000
# Ventas insertadas: 15000/50000
# Ventas insertadas: 16000/50000
# Ventas insertadas: 17000/50000
# Ventas insertadas: 18000/50000
# Ventas insertadas: 19000/50000
# Ventas insertadas: 20000/50000
# Ventas insertadas: 21000/50000
# Ventas insertadas: 22000/50000
# Ventas insertadas: 23000/50000
# Ventas insertadas: 24000/50000
# Ventas insertadas: 25000/50000
# Ventas insertadas: 26000/50000
# Ventas insertadas: 27000/50000
# Ventas insertadas: 28000/50000
# Ventas insertadas: 29000/50000
# Ventas insertadas: 30000/50000
# Ventas insertadas: 31000/50000
# Ventas insertadas: 32000/50000
# Ventas insertadas: 33000/50000
# Ventas insertadas: 34000/50000
# Ventas insertadas: 35000/50000
# Ventas insertadas: 36000/50000
# Ventas insertadas: 37000/50000
# Ventas insertadas: 38000/50000
# Ventas insertadas: 39000/50000
# Ventas insertadas: 40000/50000
# Ventas insertadas: 41000/50000
# Ventas insertadas: 42000/50000
# Ventas insertadas: 43000/50000
# Ventas insertadas: 44000/50000
# Ventas insertadas: 45000/50000
# Ventas insertadas: 46000/50000
# Ventas insertadas: 47000/50000
# Ventas insertadas: 48000/50000
# Ventas insertadas: 49000/50000
# Ventas insertadas: 50000/50000
# Registros de ventas generados e insertados

# %% [markdown]
# Data presente en Atlas:
#
# ![image.png](attachment:image.png)
